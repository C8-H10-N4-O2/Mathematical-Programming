# %%
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
from math import *

plt.rcParams["figure.figsize"] = (3, 3)

# %%
#문제 1 - (1)

def g(x,y):
    return np.sqrt(1-x**2 - y**2)

fig = plt.figure()
ax = fig.gca(projection='3d')

xrange2 = np.linspace(-1, 1, 100)
yrange2 = np.linspace(-1, 1, 100)
X2, Y2 = np.meshgrid(xrange2, yrange2)
Z2 = g(X2, Y2)
ax.plot_surface(X2, Y2, -Z2, color='lightblue', antialiased=True, edgecolor='black')
ax.plot_surface(X2, Y2, Z2, color='lightblue', antialiased=True, edgecolor='black')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">
# C:\Users\leeyesol\AppData\Local\Temp\ipykernel_17376\2320968805.py:7: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# C:\Users\leeyesol\AppData\Local\Temp\ipykernel_17376\2320968805.py:4: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(1-x**2 - y**2)

# %%
#문제 1 - (2)

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

def plot_implicit(fn, bbox=(-2.5,2.5)):
    ''' create a plot of an implicit function
    fn  ...implicit function (plot where fn==0)
    bbox ..the x,y,and z limits of plotted interval'''
    xmin, xmax, ymin, ymax, zmin, zmax = bbox*3
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    A = np.linspace(xmin, xmax, 100) # resolution of the contour
    B = np.linspace(xmin, xmax, 30) # number of slices
    A1,A2 = np.meshgrid(A,A) # grid on which the contour is plotted

    for z in B: # plot contours in the XY plane
        X,Y = A1,A2
        Z = fn(X,Y,z)
        cset = ax.contour(X, Y, Z+z, [z], zdir='z')
        # [z] defines the only level to plot for this contour for this value of z

    for y in B: # plot contours in the XZ plane
        X,Z = A1,A2
        Y = fn(X,y,Z)
        cset = ax.contour(X, Y+y, Z, [y], zdir='y')

    for x in B: # plot contours in the YZ plane
        Y,Z = A1,A2
        X = fn(x,Y,Z)
        cset = ax.contour(X+x, Y, Z, [x], zdir='x')

    # must set plot limits because the contour will likely extend
    # way beyond the displayed level.  Otherwise matplotlib extends the plot limits
    # to encompass all values in the contour.
    ax.set_zlim3d(zmin,zmax)
    ax.set_xlim3d(xmin,xmax)
    ax.set_ylim3d(ymin,ymax)

    plt.show()

def hyp_part1(x,y,z):
    return -(x**2) - (y**2) + (z**2)

plot_implicit(hyp_part1, bbox=(-100.,100.))


# 출처 https://stackoverflow.com/questions/4680525/plotting-implicit-equations-in-3d
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">
# C:\Users\leeyesol\AppData\Local\Temp\ipykernel_17376\3242576212.py:27: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\leeyesol\AppData\Local\Temp\ipykernel_17376\3242576212.py:32: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
#문제 1 - (3)
def g(x,y):
    return x**2 + y**2

fig = plt.figure()
ax = fig.gca(projection='3d')

xrange2 = np.linspace(-10, 10, 100)
yrange2 = np.linspace(-10, 10, 100)

X2, Y2 = np.meshgrid(xrange2, yrange2)
Z2 = g(X2, Y2)
ax.plot_surface(X2, Y2, Z2, color='lightblue', edgecolor='black')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">
# C:\Users\leeyesol\AppData\Local\Temp\ipykernel_17376\79892377.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
#문제 1 - (3)

from matplotlib import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import math

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
Z = (X**2 + Y**2)

ax.set_zlim(-5, 10)

ax.plot_surface(X, Y, Z,cmap=cm.summer)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="299.99999349767523">

# %%
#문제 1 - (4)

import matplotlib.pyplot as plt 
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D 
import numpy as np 
from math import *

# %matplotlib notebook

X = np.arange(-5, 5, 0.5) 
Y = np.arange(-5, 5, 0.5) 
X, Y = np.meshgrid(X, Y)

Z= np.sqrt(X**2 + Y**2 - 1)

fig = plt.figure(figsize=(5,5))

ax = plt.axes(projection='3d')

surf=ax.plot_surface(X, Y, Z, cmap=cm.coolwarm) 
surf=ax.plot_surface(X, Y, -Z, cmap=cm.coolwarm) 

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# C:\Users\leeyesol\AppData\Local\Temp\ipykernel_17376\3304278983.py:15: RuntimeWarning: invalid value encountered in sqrt
#   Z= np.sqrt(X**2 + Y**2 - 1)
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
#문제 1 - (4) - 다른방법

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=plt.figaspect(1))  # Square figure
ax = fig.add_subplot(111, projection='3d')

r=1;
u=np.linspace(-2,2,200);
v=np.linspace(0,2*np.pi,60);
[u,v]=np.meshgrid(u,v);

a = 1
b = 1
c = 1

x = a*np.cosh(u)*np.cos(v)
y = b*np.cosh(u)*np.sin(v)
z = c*np.sinh(u)

ax.plot_surface(x, y, z,  rstride=4, cstride=4)

plt.show()

출처 : https://stackoverflow.com/questions/8062248/plotting-a-hyperboloid
# Out:
# <img src="data:image/png;base64,..." width="479.9999895962804">

# %%
#문제 1 - (5)

def hyp_part5(x,y,z):
    return (x**2) - (y**2) - z

plot_implicit(hyp_part5, bbox=(-5.,5.))

# %%
#문제 1 - (6)

def g(x,y):
    return np.sqrt(1+x**2 + y**2)

fig = plt.figure()
ax = fig.gca(projection='3d')

xrange2 = np.linspace(-1, 1, 100)
yrange2 = np.linspace(-1, 1, 100)
X2, Y2 = np.meshgrid(xrange2, yrange2)
Z2 = g(X2, Y2)
ax.plot_surface(X2, Y2, -Z2, color='lightblue', antialiased=True, edgecolor='black')
ax.plot_surface(X2, Y2, Z2, color='lightblue', antialiased=True, edgecolor='black')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# C:\Users\leeyesol\AppData\Local\Temp\ipykernel_17376\145575793.py:7: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
#문제 2

from sympy import * 
from sympy.plotting import plot3d 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 5,5

x, y = symbols('x y')

f = (x**2+3*y**2)*np.e**(-(x**2)-(y**2))

plot3d(f, (x, -2, 2), (y, -2, 2)) 


#최댓값은 2개 생길것이다.
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">
